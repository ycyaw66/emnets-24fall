# %% [markdown]
# ##### 01 数据集导入，创建训练集和测试集。通过查看注释，理解整个流程。

# %%
import glob
import numpy as np
# 训练集、测试集划分
from sklearn.model_selection import train_test_split
# 数据集相对路径
DATA_PATH = "../../../10_tingml_datasets/"
# LABELS 的内容尽量与前面store_data.py保持一致
LABELS = ["Stationary", "Tilted", "Rotating", "Moving"]
# 代表一个样本内容，如连续10次传感器读到的6轴数据作为一个样本
SAMPLES_PER_GESTURE = 10
def load_one_label_data(label):
    path = DATA_PATH + label + "*.npy"
    files = glob.glob(path)
    datas = []
    for file in files:
        try:
            data = np.load(file)
            # 切除多余数据，如数据当中有61份，但每个样本只需要10份，那么最后一份需要丢弃。
            num_slice = len(data) // SAMPLES_PER_GESTURE
            datas.append(data[: num_slice * SAMPLES_PER_GESTURE, :])
        except Exception as e:
            print(e)
    datas = np.concatenate(datas, axis=0)
    # 由于本案例给的是全连接层，输入为1维数据。(其余如conv需要自行根据模型输入修改尺寸，如二维)
    # MLP
    # datas = np.reshape(datas,(-1, 6 * SAMPLES_PER_GESTURE,),)  # Modified here
    # CNN 1
    # datas = np.reshape(datas,(-1, 6 * SAMPLES_PER_GESTURE, 1),)  # Modified here
    # CNN 2, height = SAMPLES_PER_GESTURE, width = 6
    datas = np.reshape(datas,(-1, SAMPLES_PER_GESTURE, 6, 1),) # Modified here
    
    idx = LABELS.index(label)
    labels = np.ones(datas.shape[0]) * idx
    return datas, labels
all_datas = []
all_labels = []
# 导入每个label对应的数据
for label in LABELS:
    datas, labels = load_one_label_data(label)
    all_datas.append(datas)
    all_labels.append(labels)
dataX = np.concatenate(all_datas, axis=0)
dataY = np.concatenate(all_labels, axis=0)
# 输入和样本到此创建完毕

# 训练集、测试集划分
# test_size 表示数据集里面有20%将划分给测试集
# stratify=dataY指定按label进行划分, 确保数据集划分公平
xTrain, xTest, yTrain, yTest = train_test_split(
    dataX, dataY, test_size=0.2, stratify=dataY
)
print(xTrain.shape, xTest.shape, yTrain.shape, yTest.shape)
# Out:
# (1328, 60, 1) (332, 60, 1) (1328,) (332,)

# %% [markdown]
# ##### 02 模型创建
# 下面将创建很简单的多层感知机模型，后续可自行定义模型结构。需要根据自身需求，自行上网查询其他模型，如CNN，切记模型不要太大，嵌入式设备大致提供32K空间供运行模型。
# 模型需要注意输入尺寸，如CNN往往多维数据，如**Conv1d 输入二维，可将输入改为(6 * SAMPLES_PER_GESTURE,1)或者(SAMPLES_PER_GESTURE, 6), 上面数据集对应尺寸也需要修改**

# %%
import os
# 0 = INFO, 1 = WARNING, 2 = ERROR, 3 = FATAL
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf
import tensorflow.keras as keras
SAMPLES_PER_GESTURE = 10
LABELS = ["Stationary", "Tilted", "Rotating", "Moving"]

# 设置环境变量，控制日志级别
def mlp():
    # 一个用于线性堆叠多个网络层的模型。
    # Sequential模型是最简单的神经网络模型，它按照层的顺序依次堆叠，每一层的输出会成为下一层的输入。
    model = keras.Sequential()
    # 第一层, 添加全连接层，输出尺寸为64，激活函数采用"relu"
    # 第一层需要制定输入大小，这里和数据集对应input_shape=(6 * SAMPLES_PER_GESTURE,)
    model.add(keras.layers.Dense(64, activation="relu", input_shape=(6 * SAMPLES_PER_GESTURE,)))
    # 添加池化层，防止模型过拟合，每次自动忘记20%的参数
    model.add(keras.layers.Dropout(0.2))
    # 最后一层，全连接层，输出尺寸对应labels数量，激活函数采用"softmax"
    # softmaxs输出的结果代表每个label的概率，如第0个代表label 0的概率
    model.add(keras.layers.Dense(len(LABELS), activation="softmax"))
    return model
def cnn():
    # 一个用于线性堆叠多个网络层的模型。
    # Sequential模型是最简单的神经网络模型，它按照层的顺序依次堆叠，每一层的输出会成为下一层的输入。
    model = keras.Sequential()
    # 注意CNN与MLP的输入shape
    # 16个输出通道，3为卷积核大小
    model.add(
        keras.layers.Conv1D(
            8,3,padding="same",activation="relu",input_shape=(6 * SAMPLES_PER_GESTURE, 1),
        )
    )
    model.add(keras.layers.Conv1D(8, 3, padding="same", activation="relu"))
    model.add(keras.layers.GlobalAveragePooling1D())
    model.add(keras.layers.Dense(8, activation="relu"))
    model.add(keras.layers.Dropout(0.2))
    model.add(keras.layers.Dense(len(LABELS), activation="softmax"))
    return model
def cnn_2d():
    model = keras.Sequential()
    model.add(
        keras.layers.Conv2D(
            filters=8,
            kernel_size=(3, 3),
            padding="same",
            activation="relu",
            input_shape=(SAMPLES_PER_GESTURE, 6, 1),
        )
    )
    model.add(keras.layers.Conv2D(8, (3, 3), padding="same", activation="relu"))
    model.add(keras.layers.GlobalAveragePooling2D())
    model.add(keras.layers.Dense(16, activation="relu"))
    model.add(keras.layers.Dropout(0.2))
    model.add(keras.layers.Dense(len(LABELS), activation="softmax"))
    return model

model = cnn_2d()
# 打印模型结构
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 60, 8)             32
#
#  conv1d_9 (Conv1D)           (None, 60, 8)             200
#
#  global_average_pooling1d_4  (None, 8)                 0
#   (GlobalAveragePooling1D)
#
#  dense_37 (Dense)            (None, 8)                 72
#
#  dropout_19 (Dropout)        (None, 8)                 0
#
#  dense_38 (Dense)            (None, 4)                 36
#
# =================================================================
# Total params: 340 (1.33 KB)
# Trainable params: 340 (1.33 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### 03 模型训练及测试

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# 加载模型
from tensorflow.keras.models import load_model
# 测试模型性能
from sklearn.metrics import confusion_matrix
# 模型训练优化器，学习率为0.001
optimizer = keras.optimizers.Adam(lr=0.001)
# 制定模型优化器，和损失函数、评价指标
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=optimizer,
    metrics=["sparse_categorical_accuracy"],
)
# 制定保存模型的路径
filepath = "best_model.h5"
model.save(filepath)
# 训练时，保存最好模型
checkpoint = ModelCheckpoint(
    filepath,
    monitor="val_sparse_categorical_accuracy",
    verbose=1,
    save_best_only=True,
    mode="max",
)
# 模型训练, 训练集，batch_size为批大小，可提高训练速度
# validation_data指明验证集，epochs表示训练迭代轮数
# verbose=1表示打印训练日志
# callbacks调用上述保存模型的方法
history = model.fit(
    xTrain,
    yTrain,
    batch_size=8,
    validation_data=(xTest, yTest),
    epochs=50,
    verbose=1,
    callbacks=[checkpoint],
)
# 至此模型训练完毕
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 125/166 [=====================>........] - ETA: 0s - loss: 2.1502 - sparse_categorical_accuracy: 0.3160
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.54217, saving model to best_model.h5
# 166/166 [==============================] - 1s 2ms/step - loss: 1.8935 - sparse_categorical_accuracy: 0.3502 - val_loss: 1.0873 - val_sparse_categorical_accuracy: 0.5422
# Epoch 2/50
# 143/166 [========================>.....] - ETA: 0s - loss: 1.0732 - sparse_categorical_accuracy: 0.5332
# Epoch 2: val_sparse_categorical_accuracy improved from 0.54217 to 0.65060, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 1.0649 - sparse_categorical_accuracy: 0.5392 - val_loss: 1.0110 - val_sparse_categorical_accuracy: 0.6506
# Epoch 3/50
# 140/166 [========================>.....] - ETA: 0s - loss: 1.0162 - sparse_categorical_accuracy: 0.6134
# Epoch 3: val_sparse_categorical_accuracy improved from 0.65060 to 0.67169, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 1.0034 - sparse_categorical_accuracy: 0.6182 - val_loss: 0.9469 - val_sparse_categorical_accuracy: 0.6717
# Epoch 4/50
# 138/166 [=======================>......] - ETA: 0s - loss: 0.9636 - sparse_categorical_accuracy: 0.6286
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.67169
# 166/166 [==============================] - 0s 2ms/step - loss: 0.9392 - sparse_categorical_accuracy: 0.6386 - val_loss: 0.8737 - val_sparse_categorical_accuracy: 0.6476
# Epoch 5/50
# 136/166 [=======================>......] - ETA: 0s - loss: 0.8917 - sparse_categorical_accuracy: 0.6278
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.67169
# 166/166 [==============================] - 0s 1ms/step - loss: 0.8832 - sparse_categorical_accuracy: 0.6265 - val_loss: 0.8273 - val_sparse_categorical_accuracy: 0.6596
# Epoch 6/50
# 142/166 [========================>.....] - ETA: 0s - loss: 0.8223 - sparse_categorical_accuracy: 0.6585
# Epoch 6: val_sparse_categorical_accuracy improved from 0.67169 to 0.71386, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 0.8247 - sparse_categorical_accuracy: 0.6551 - val_loss: 0.7768 - val_sparse_categorical_accuracy: 0.7139
# Epoch 7/50
# 162/166 [============================>.] - ETA: 0s - loss: 0.7763 - sparse_categorical_accuracy: 0.6829
# Epoch 7: val_sparse_categorical_accuracy improved from 0.71386 to 0.71988, saving model to best_model.h5
# 166/166 [==============================] - 0s 2ms/step - loss: 0.7735 - sparse_categorical_accuracy: 0.6837 - val_loss: 0.7344 - val_sparse_categorical_accuracy: 0.7199
# Epoch 8/50
# 134/166 [=======================>......] - ETA: 0s - loss: 0.7397 - sparse_categorical_accuracy: 0.6959
# Epoch 8: val_sparse_categorical_accuracy improved from 0.71988 to 0.73795, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 0.7338 - sparse_categorical_accuracy: 0.6980 - val_loss: 0.6607 - val_sparse_categorical_accuracy: 0.7380
# Epoch 9/50
# 142/166 [========================>.....] - ETA: 0s - loss: 0.6632 - sparse_categorical_accuracy: 0.7350
# Epoch 9: val_sparse_categorical_accuracy improved from 0.73795 to 0.76506, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 0.6641 - sparse_categorical_accuracy: 0.7297 - val_loss: 0.5894 - val_sparse_categorical_accuracy: 0.7651
# Epoch 10/50
# 137/166 [=======================>......] - ETA: 0s - loss: 0.6309 - sparse_categorical_accuracy: 0.7391
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.76506
# 166/166 [==============================] - 0s 1ms/step - loss: 0.6277 - sparse_categorical_accuracy: 0.7372 - val_loss: 0.5622 - val_sparse_categorical_accuracy: 0.7651
# Epoch 11/50
# 161/166 [============================>.] - ETA: 0s - loss: 0.5860 - sparse_categorical_accuracy: 0.7500
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.76506
# 166/166 [==============================] - 0s 2ms/step - loss: 0.5811 - sparse_categorical_accuracy: 0.7523 - val_loss: 0.5145 - val_sparse_categorical_accuracy: 0.7590
# Epoch 12/50
# 136/166 [=======================>......] - ETA: 0s - loss: 0.5347 - sparse_categorical_accuracy: 0.7491
# Epoch 12: val_sparse_categorical_accuracy improved from 0.76506 to 0.77410, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 0.5300 - sparse_categorical_accuracy: 0.7530 - val_loss: 0.4563 - val_sparse_categorical_accuracy: 0.7741
# Epoch 13/50
# 141/166 [========================>.....] - ETA: 0s - loss: 0.5016 - sparse_categorical_accuracy: 0.7757
# Epoch 13: val_sparse_categorical_accuracy improved from 0.77410 to 0.77711, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4919 - sparse_categorical_accuracy: 0.7839 - val_loss: 0.4157 - val_sparse_categorical_accuracy: 0.7771
# Epoch 14/50
# 145/166 [=========================>....] - ETA: 0s - loss: 0.4389 - sparse_categorical_accuracy: 0.8422
# Epoch 14: val_sparse_categorical_accuracy improved from 0.77711 to 0.98494, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4495 - sparse_categorical_accuracy: 0.8509 - val_loss: 0.3692 - val_sparse_categorical_accuracy: 0.9849
# Epoch 15/50
# 146/166 [=========================>....] - ETA: 0s - loss: 0.4349 - sparse_categorical_accuracy: 0.8904
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.98494
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4257 - sparse_categorical_accuracy: 0.8968 - val_loss: 0.3391 - val_sparse_categorical_accuracy: 0.9789
# Epoch 16/50
# 145/166 [=========================>....] - ETA: 0s - loss: 0.3891 - sparse_categorical_accuracy: 0.9397
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.98494
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3908 - sparse_categorical_accuracy: 0.9383 - val_loss: 0.3123 - val_sparse_categorical_accuracy: 0.9759
# Epoch 17/50
# 144/166 [=========================>....] - ETA: 0s - loss: 0.3618 - sparse_categorical_accuracy: 0.9418
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.98494
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3718 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.3050 - val_sparse_categorical_accuracy: 0.9669
# Epoch 18/50
# 144/166 [=========================>....] - ETA: 0s - loss: 0.3298 - sparse_categorical_accuracy: 0.9505
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.98494
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3357 - sparse_categorical_accuracy: 0.9443 - val_loss: 0.2515 - val_sparse_categorical_accuracy: 0.9819
# Epoch 19/50
# 140/166 [========================>.....] - ETA: 0s - loss: 0.3042 - sparse_categorical_accuracy: 0.9473
# Epoch 19: val_sparse_categorical_accuracy improved from 0.98494 to 0.99398, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3036 - sparse_categorical_accuracy: 0.9503 - val_loss: 0.2152 - val_sparse_categorical_accuracy: 0.9940
# Epoch 20/50
# 140/166 [========================>.....] - ETA: 0s - loss: 0.3108 - sparse_categorical_accuracy: 0.9277
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.99398
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3204 - sparse_categorical_accuracy: 0.9315 - val_loss: 0.2385 - val_sparse_categorical_accuracy: 0.9819
# Epoch 21/50
# 145/166 [=========================>....] - ETA: 0s - loss: 0.3132 - sparse_categorical_accuracy: 0.9474
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.99398
# 166/166 [==============================] - 0s 1ms/step - loss: 0.3131 - sparse_categorical_accuracy: 0.9443 - val_loss: 0.1817 - val_sparse_categorical_accuracy: 0.9880
# Epoch 22/50
# 138/166 [=======================>......] - ETA: 0s - loss: 0.2758 - sparse_categorical_accuracy: 0.9420
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.99398
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2751 - sparse_categorical_accuracy: 0.9420 - val_loss: 0.1682 - val_sparse_categorical_accuracy: 0.9940
# Epoch 23/50
# 141/166 [========================>.....] - ETA: 0s - loss: 0.2476 - sparse_categorical_accuracy: 0.9486
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.99398
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2447 - sparse_categorical_accuracy: 0.9495 - val_loss: 0.1478 - val_sparse_categorical_accuracy: 0.9910
# Epoch 24/50
# 142/166 [========================>.....] - ETA: 0s - loss: 0.2323 - sparse_categorical_accuracy: 0.9454
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.99398
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2285 - sparse_categorical_accuracy: 0.9465 - val_loss: 0.1343 - val_sparse_categorical_accuracy: 0.9880
# Epoch 25/50
# 144/166 [=========================>....] - ETA: 0s - loss: 0.2037 - sparse_categorical_accuracy: 0.9540
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.99398
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2072 - sparse_categorical_accuracy: 0.9518 - val_loss: 0.1141 - val_sparse_categorical_accuracy: 0.9940
# Epoch 26/50
# 146/166 [=========================>....] - ETA: 0s - loss: 0.1916 - sparse_categorical_accuracy: 0.9632
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.99398
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1966 - sparse_categorical_accuracy: 0.9608 - val_loss: 0.1136 - val_sparse_categorical_accuracy: 0.9880
# Epoch 27/50
# 146/166 [=========================>....] - ETA: 0s - loss: 0.1894 - sparse_categorical_accuracy: 0.9546
# Epoch 27: val_sparse_categorical_accuracy improved from 0.99398 to 0.99699, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1926 - sparse_categorical_accuracy: 0.9503 - val_loss: 0.0920 - val_sparse_categorical_accuracy: 0.9970
# Epoch 28/50
# 145/166 [=========================>....] - ETA: 0s - loss: 0.2188 - sparse_categorical_accuracy: 0.9474
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2126 - sparse_categorical_accuracy: 0.9495 - val_loss: 0.1016 - val_sparse_categorical_accuracy: 0.9970
# Epoch 29/50
# 148/166 [=========================>....] - ETA: 0s - loss: 0.1762 - sparse_categorical_accuracy: 0.9586
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1771 - sparse_categorical_accuracy: 0.9571 - val_loss: 0.0803 - val_sparse_categorical_accuracy: 0.9970
# Epoch 30/50
# 146/166 [=========================>....] - ETA: 0s - loss: 0.1742 - sparse_categorical_accuracy: 0.9580
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1717 - sparse_categorical_accuracy: 0.9586 - val_loss: 0.0754 - val_sparse_categorical_accuracy: 0.9970
# Epoch 31/50
# 148/166 [=========================>....] - ETA: 0s - loss: 0.1591 - sparse_categorical_accuracy: 0.9611
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1613 - sparse_categorical_accuracy: 0.9616 - val_loss: 0.0759 - val_sparse_categorical_accuracy: 0.9970
# Epoch 32/50
# 150/166 [==========================>...] - ETA: 0s - loss: 0.1511 - sparse_categorical_accuracy: 0.9658
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1519 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.0694 - val_sparse_categorical_accuracy: 0.9970
# Epoch 33/50
# 144/166 [=========================>....] - ETA: 0s - loss: 0.1656 - sparse_categorical_accuracy: 0.9540
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1628 - sparse_categorical_accuracy: 0.9571 - val_loss: 0.0616 - val_sparse_categorical_accuracy: 0.9970
# Epoch 34/50
# 145/166 [=========================>....] - ETA: 0s - loss: 0.1575 - sparse_categorical_accuracy: 0.9655
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1541 - sparse_categorical_accuracy: 0.9661 - val_loss: 0.0587 - val_sparse_categorical_accuracy: 0.9970
# Epoch 35/50
# 148/166 [=========================>....] - ETA: 0s - loss: 0.1431 - sparse_categorical_accuracy: 0.9645
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1378 - sparse_categorical_accuracy: 0.9669 - val_loss: 0.0521 - val_sparse_categorical_accuracy: 0.9970
# Epoch 36/50
# 142/166 [========================>.....] - ETA: 0s - loss: 0.1479 - sparse_categorical_accuracy: 0.9639
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1506 - sparse_categorical_accuracy: 0.9661 - val_loss: 0.0547 - val_sparse_categorical_accuracy: 0.9970
# Epoch 37/50
# 127/166 [=====================>........] - ETA: 0s - loss: 0.1649 - sparse_categorical_accuracy: 0.9537
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1528 - sparse_categorical_accuracy: 0.9586 - val_loss: 0.0547 - val_sparse_categorical_accuracy: 0.9970
# Epoch 38/50
# 148/166 [=========================>....] - ETA: 0s - loss: 0.1270 - sparse_categorical_accuracy: 0.9755
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1243 - sparse_categorical_accuracy: 0.9759 - val_loss: 0.0504 - val_sparse_categorical_accuracy: 0.9970
# Epoch 39/50
# 145/166 [=========================>....] - ETA: 0s - loss: 0.1370 - sparse_categorical_accuracy: 0.9629
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1349 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.0443 - val_sparse_categorical_accuracy: 0.9970
# Epoch 40/50
# 140/166 [========================>.....] - ETA: 0s - loss: 0.1211 - sparse_categorical_accuracy: 0.9688
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1249 - sparse_categorical_accuracy: 0.9661 - val_loss: 0.0440 - val_sparse_categorical_accuracy: 0.9970
# Epoch 41/50
# 143/166 [========================>.....] - ETA: 0s - loss: 0.1300 - sparse_categorical_accuracy: 0.9694
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1299 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.0381 - val_sparse_categorical_accuracy: 0.9970
# Epoch 42/50
# 139/166 [========================>.....] - ETA: 0s - loss: 0.1303 - sparse_categorical_accuracy: 0.9703
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1247 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.0501 - val_sparse_categorical_accuracy: 0.9970
# Epoch 43/50
# 140/166 [========================>.....] - ETA: 0s - loss: 0.1440 - sparse_categorical_accuracy: 0.9705
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1442 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.0443 - val_sparse_categorical_accuracy: 0.9970
# Epoch 44/50
# 142/166 [========================>.....] - ETA: 0s - loss: 0.1319 - sparse_categorical_accuracy: 0.9648
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1280 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.0377 - val_sparse_categorical_accuracy: 0.9970
# Epoch 45/50
# 140/166 [========================>.....] - ETA: 0s - loss: 0.1122 - sparse_categorical_accuracy: 0.9714
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1225 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.0362 - val_sparse_categorical_accuracy: 0.9970
# Epoch 46/50
# 139/166 [========================>.....] - ETA: 0s - loss: 0.1184 - sparse_categorical_accuracy: 0.9658
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1162 - sparse_categorical_accuracy: 0.9669 - val_loss: 0.0359 - val_sparse_categorical_accuracy: 0.9970
# Epoch 47/50
# 138/166 [=======================>......] - ETA: 0s - loss: 0.1145 - sparse_categorical_accuracy: 0.9701
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1187 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.0349 - val_sparse_categorical_accuracy: 0.9970
# Epoch 48/50
# 137/166 [=======================>......] - ETA: 0s - loss: 0.1195 - sparse_categorical_accuracy: 0.9672
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1136 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.0335 - val_sparse_categorical_accuracy: 0.9970
# Epoch 49/50
# 145/166 [=========================>....] - ETA: 0s - loss: 0.1224 - sparse_categorical_accuracy: 0.9664
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1174 - sparse_categorical_accuracy: 0.9684 - val_loss: 0.0360 - val_sparse_categorical_accuracy: 0.9940
# Epoch 50/50
# 145/166 [=========================>....] - ETA: 0s - loss: 0.1085 - sparse_categorical_accuracy: 0.9716
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1106 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.0307 - val_sparse_categorical_accuracy: 0.9970

# %%
# 加载模型
model = load_model(filepath)
# 模型推理，预测
predictions = model.predict(xTest)
predictions = np.argmax(predictions, axis=1)
# 查看混淆矩阵，效果越好，预测则集中在对角线。
cm = confusion_matrix(yTest, predictions)
print(cm)
# Out:
# 11/11 [==============================] - 0s 955us/step
# [[ 68   0   0   0]
#  [  0  84   0   0]
#  [  0   0  76   0]
#  [  1   0   0 103]]

# %% [markdown]
# 由于运动状态简单，上述最简单的模型可能也会获得不错的性能，当运动状态变得复杂，上述MLP模型性能将很难满足需求。
# #### 04 生成最终部署的模型
# 由于RIOT系统使用的时tflite-micro库且资源有限，将模型量化，并保存成tflite-micro可识别的格式，注意
# `data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, ))`后的尺寸维度和大小需要和前面大致对应

# %%
# Convert the model to the TensorFlow Lite format with quantization
# 加载模型
model = load_model(filepath)
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# 设置目标操作集，允许使用 TensorFlow 原生操作
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,  # 使用TFLite的内置操作
    tf.lite.OpsSet.SELECT_TF_OPS     # 允许使用部分TensorFlow的操作
]

# 禁用 tensor list ops 的低级优化
converter._experimental_lower_tensor_list_ops = False

tflite_model = converter.convert()
# 保存初始版本，后续对比用
open("model_basic.tflite", "wb").write(tflite_model)
open("model.tflite", "wb").write(tflite_model)

# 量化模型, 定义输入格式与大小，只需要修改(-1, 6 * SAMPLES_PER_GESTURE,)与上面对应即可，其余不用变
data_test = xTest.astype("float32")
# np.reshape 和一开始数据集导入对应
# MLP
# data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, ))
# CNN 1
# data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, 1))
# CNN 2
data_test = np.reshape(data_test, (-1, SAMPLES_PER_GESTURE, 6, 1))
data_ds = tf.data.Dataset.from_tensor_slices((data_test)).batch(1)

# Rest of your code...
def representative_data_gen():
    for input_value in data_ds.take(100):
        yield [input_value]
converter.representative_dataset = representative_data_gen
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()
open("model.tflite", "wb").write(tflite_model)

# 量化前后对比
basic_model_size = os.path.getsize("model_basic.tflite")
print("Basic model is %d bytes" % basic_model_size)
quantized_model_size = os.path.getsize("model.tflite")
print("Quantized model is %d bytes" % quantized_model_size)
difference = basic_model_size - quantized_model_size
print("Difference is %d bytes" % difference)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpta0hm_z5/assets
# INFO:tensorflow:Assets written to: /tmp/tmpta0hm_z5/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# INFO:tensorflow:Assets written to: /tmp/tmpcohyddd8/assets
# INFO:tensorflow:Assets written to: /tmp/tmpcohyddd8/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# /usr/local/lib/python3.8/dist-packages/tensorflow/lite/python/convert.py:887: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Basic model is 5768 bytes
# Quantized model is 6160 bytes
# Difference is -392 bytes
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32

# %% [markdown]
# 前面，通过量化，帮助我们模型节省了2440Bytes大小。需要验证量化后的模型输入格式和尺寸是否正确

# %%
# Now let's verify the model on a few input digits
# Instantiate an interpreter for the model
model_quantized_reloaded = tf.lite.Interpreter("model.tflite")

# Allocate memory for each model
model_quantized_reloaded.allocate_tensors()

# Get the input and output tensors so we can feed in values and get the results
model_quantized_input = model_quantized_reloaded.get_input_details()[0]["index"]
model_quantized_output = model_quantized_reloaded.get_output_details()[0]["index"]
# Create arrays to store the results
model_quantized_predictions = np.empty(xTest.size)

count = 0

for i in range(yTest.shape[0]):
    # Reshape the data and ensure the type is float32
    # test_data = np.reshape(
    #     xTest[i],
    #     (
    #         1,
    #         6 * SAMPLES_PER_GESTURE,
    #         1,
    #     ),
    # ).astype("float32")
    test_data = np.expand_dims(xTest[i], axis=0).astype("float32")
    print(test_data.shape)
    # Invoke the interpreter
    model_quantized_reloaded.set_tensor(model_quantized_input, test_data)
    model_quantized_reloaded.invoke()
    model_quantized_prediction = model_quantized_reloaded.get_tensor(
        model_quantized_output
    )
    result = np.argmax(model_quantized_prediction, axis=1)
    if (result == yTest[i]):
        count = count + 1
    print("Digit: {} - Prediction:\n{}".format(yTest[i], model_quantized_prediction))
    print("")

print(count / yTest.shape[0])
# Out:
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.00390625]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.01953125 0.9765625 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.00390625 0.01953125 0.9765625 ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.98046875 0.01953125]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.00390625 0.859375   0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.01953125 0.01953125 0.9609375 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.109375 0.       0.109375 0.78125 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.12109375 0.87890625]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.98046875 0.01953125]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.00390625 0.859375   0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.         0.015625   0.86328125]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.12109375 0.875     ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.12109375 0.87890625]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.00390625 0.01953125 0.9765625 ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.015625   0.         0.12109375 0.86328125]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.00390625]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.09765625 0.09765625 0.09765625 0.703125  ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.015625   0.         0.12109375 0.86328125]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.00390625]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.0625 0.4375 0.0625 0.4375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.01953125 0.00390625 0.01953125 0.9609375 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.01953125 0.00390625 0.01953125 0.9609375 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.  0.  0.5 0.5]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.12109375 0.87890625]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.109375   0.76953125 0.015625   0.109375  ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.0078125  0.46484375 0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.015625   0.         0.12109375 0.86328125]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.  0.  0.5 0.5]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.12109375 0.875     ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.12109375 0.87890625]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.00390625 0.859375   0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.00390625 0.859375   0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.109375 0.       0.109375 0.78125 ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.01953125 0.9765625 ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.0625 0.4375 0.0625 0.4375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.01953125 0.9765625 ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.         0.015625   0.86328125]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.9765625  0.00390625 0.01953125]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.01953125 0.9765625 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.109375   0.76953125 0.015625   0.109375  ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.00390625]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.01953125 0.9765625 ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.01953125 0.         0.01953125 0.9609375 ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.12109375 0.87890625]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.12109375 0.87890625]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.00390625 0.859375   0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.12109375 0.87890625]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.12109375 0.875     ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.         0.015625   0.86328125]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.015625   0.         0.12109375 0.86328125]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.0078125  0.46484375 0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.9765625  0.00390625 0.01953125]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.01953125 0.01953125 0.9609375 ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.0078125  0.46484375 0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.00390625 0.859375   0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.109375   0.76953125 0.015625   0.109375  ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.00390625 0.859375   0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.00390625]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.0625 0.4375 0.0625 0.4375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.01953125 0.         0.01953125 0.9609375 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.  0.  0.5 0.5]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.12109375 0.875     ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.015625   0.         0.12109375 0.86328125]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.00390625]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.109375   0.76953125 0.015625   0.109375  ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.00390625 0.99609375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.         0.015625   0.86328125]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.00390625 0.015625   0.859375  ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.015625   0.         0.12109375 0.86328125]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.         0.015625   0.86328125]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.9765625  0.00390625 0.01953125]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.01953125 0.9765625 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.         0.015625   0.86328125]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.109375 0.       0.109375 0.78125 ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.98046875 0.01953125]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.00390625 0.01953125 0.9765625 ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.9765625  0.00390625 0.01953125]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.00390625 0.015625   0.859375  ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.015625   0.         0.12109375 0.86328125]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.         0.015625   0.86328125]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.00390625 0.859375   0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.         0.015625   0.86328125]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.00390625 0.859375   0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.99609375 0.         0.00390625]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.01953125 0.00390625 0.01953125 0.9609375 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.         0.015625   0.86328125]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.00390625 0.859375   0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.109375 0.       0.109375 0.78125 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.01953125 0.00390625 0.01953125 0.9609375 ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.00390625 0.12109375 0.875     ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.01953125 0.         0.01953125 0.9609375 ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.015625   0.109375   0.109375   0.76953125]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.0078125  0.46484375 0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.9765625  0.00390625 0.01953125]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.01953125 0.01953125 0.9609375 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.01953125 0.9765625 ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.9765625  0.00390625 0.01953125]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.         0.015625   0.86328125]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.01953125 0.00390625 0.01953125 0.9609375 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.015625   0.         0.12109375 0.86328125]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.00390625 0.859375   0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.12109375 0.875     ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.015625   0.         0.12109375 0.86328125]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.0625 0.4375 0.0625 0.4375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.015625   0.84765625 0.015625   0.1171875 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.12109375 0.         0.015625   0.86328125]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.00390625 0.01953125 0.9765625 ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.98046875]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.01953125 0.9765625 ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.0625 0.4375 0.0625 0.4375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.86328125 0.015625   0.12109375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.46484375 0.0078125  0.06640625 0.46484375]]
#
# 0.9548192771084337
