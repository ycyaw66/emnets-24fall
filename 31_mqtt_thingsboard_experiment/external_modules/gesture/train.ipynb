# %% [markdown]
# ##### 01 数据集导入，创建训练集和测试集。通过查看注释，理解整个流程。

# %%
import glob
import numpy as np
# 训练集、测试集划分
from sklearn.model_selection import train_test_split
# 数据集相对路径
DATA_PATH = "../../../10_tingml_datasets/"
# LABELS 的内容尽量与前面store_data.py保持一致
LABELS = ["Stationary", "Tilted", "Rotating", "Moving"]
# 代表一个样本内容，如连续10次传感器读到的6轴数据作为一个样本
SAMPLES_PER_GESTURE = 10
def load_one_label_data(label):
    path = DATA_PATH + label + "*.npy"
    files = glob.glob(path)
    datas = []
    for file in files:
        try:
            data = np.load(file)
            # 切除多余数据，如数据当中有61份，但每个样本只需要10份，那么最后一份需要丢弃。
            num_slice = len(data) // SAMPLES_PER_GESTURE
            datas.append(data[: num_slice * SAMPLES_PER_GESTURE, :])
        except Exception as e:
            print(e)
    datas = np.concatenate(datas, axis=0)
    # 由于本案例给的是全连接层，输入为1维数据。(其余如conv需要自行根据模型输入修改尺寸，如二维)
    # MLP
    # datas = np.reshape(datas,(-1, 6 * SAMPLES_PER_GESTURE,),)  # Modified here
    # CNN 1
    # datas = np.reshape(datas,(-1, 6 * SAMPLES_PER_GESTURE, 1),)  # Modified here
    # CNN 2, height = SAMPLES_PER_GESTURE, width = 6
    datas = np.reshape(datas,(-1, SAMPLES_PER_GESTURE, 6, 1),) # Modified here
    
    idx = LABELS.index(label)
    labels = np.ones(datas.shape[0]) * idx
    return datas, labels
all_datas = []
all_labels = []
# 导入每个label对应的数据
for label in LABELS:
    datas, labels = load_one_label_data(label)
    all_datas.append(datas)
    all_labels.append(labels)
dataX = np.concatenate(all_datas, axis=0)
dataY = np.concatenate(all_labels, axis=0)
# 输入和样本到此创建完毕

# 训练集、测试集划分
# test_size 表示数据集里面有20%将划分给测试集
# stratify=dataY指定按label进行划分, 确保数据集划分公平
xTrain, xTest, yTrain, yTest = train_test_split(
    dataX, dataY, test_size=0.2, stratify=dataY
)
print(xTrain.shape, xTest.shape, yTrain.shape, yTest.shape)
# Out:
# (1328, 10, 6, 1) (332, 10, 6, 1) (1328,) (332,)

# %% [markdown]
# ##### 02 模型创建
# 下面将创建很简单的多层感知机模型，后续可自行定义模型结构。需要根据自身需求，自行上网查询其他模型，如CNN，切记模型不要太大，嵌入式设备大致提供32K空间供运行模型。
# 模型需要注意输入尺寸，如CNN往往多维数据，如**Conv1d 输入二维，可将输入改为(6 * SAMPLES_PER_GESTURE,1)或者(SAMPLES_PER_GESTURE, 6), 上面数据集对应尺寸也需要修改**

# %%
import os
# 0 = INFO, 1 = WARNING, 2 = ERROR, 3 = FATAL
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf
import tensorflow.keras as keras
SAMPLES_PER_GESTURE = 10
LABELS = ["Stationary", "Tilted", "Rotating", "Moving"]

# 设置环境变量，控制日志级别
def mlp():
    # 一个用于线性堆叠多个网络层的模型。
    # Sequential模型是最简单的神经网络模型，它按照层的顺序依次堆叠，每一层的输出会成为下一层的输入。
    model = keras.Sequential()
    # 第一层, 添加全连接层，输出尺寸为64，激活函数采用"relu"
    # 第一层需要制定输入大小，这里和数据集对应input_shape=(6 * SAMPLES_PER_GESTURE,)
    model.add(keras.layers.Dense(64, activation="relu", input_shape=(6 * SAMPLES_PER_GESTURE,)))
    # 添加池化层，防止模型过拟合，每次自动忘记20%的参数
    model.add(keras.layers.Dropout(0.2))
    # 最后一层，全连接层，输出尺寸对应labels数量，激活函数采用"softmax"
    # softmaxs输出的结果代表每个label的概率，如第0个代表label 0的概率
    model.add(keras.layers.Dense(len(LABELS), activation="softmax"))
    return model
def cnn():
    # 一个用于线性堆叠多个网络层的模型。
    # Sequential模型是最简单的神经网络模型，它按照层的顺序依次堆叠，每一层的输出会成为下一层的输入。
    model = keras.Sequential()
    # 注意CNN与MLP的输入shape
    # 16个输出通道，3为卷积核大小
    model.add(
        keras.layers.Conv1D(
            8,3,padding="same",activation="relu",input_shape=(6 * SAMPLES_PER_GESTURE, 1),
        )
    )
    model.add(keras.layers.Conv1D(8, 3, padding="same", activation="relu"))
    model.add(keras.layers.GlobalAveragePooling1D())
    model.add(keras.layers.Dense(8, activation="relu"))
    model.add(keras.layers.Dropout(0.2))
    model.add(keras.layers.Dense(len(LABELS), activation="softmax"))
    return model
def cnn_2d():
    model = keras.Sequential()
    model.add(
        keras.layers.Conv2D(
            filters=8,
            kernel_size=(3, 3),
            padding="same",
            activation="relu",
            input_shape=(SAMPLES_PER_GESTURE, 6, 1),
        )
    )
    model.add(keras.layers.Conv2D(8, (3, 3), padding="same", activation="relu"))
    model.add(keras.layers.GlobalAveragePooling2D())
    model.add(keras.layers.Dense(16, activation="relu"))
    model.add(keras.layers.Dropout(0.2))
    model.add(keras.layers.Dense(len(LABELS), activation="softmax"))
    return model

model = cnn_2d()
# 打印模型结构
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 10, 6, 8)          80
#
#  conv2d_5 (Conv2D)           (None, 10, 6, 8)          584
#
#  global_average_pooling2d_2  (None, 8)                 0
#   (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 16)                144
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_5 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 876 (3.42 KB)
# Trainable params: 876 (3.42 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### 03 模型训练及测试

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# 加载模型
from tensorflow.keras.models import load_model
# 测试模型性能
from sklearn.metrics import confusion_matrix
# 模型训练优化器，学习率为0.001
optimizer = keras.optimizers.Adam(lr=0.001)
# 制定模型优化器，和损失函数、评价指标
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=optimizer,
    metrics=["sparse_categorical_accuracy"],
)
# 制定保存模型的路径
filepath = "best_model.h5"
model.save(filepath)
# 训练时，保存最好模型
checkpoint = ModelCheckpoint(
    filepath,
    monitor="val_sparse_categorical_accuracy",
    verbose=1,
    save_best_only=True,
    mode="max",
)
# 模型训练, 训练集，batch_size为批大小，可提高训练速度
# validation_data指明验证集，epochs表示训练迭代轮数
# verbose=1表示打印训练日志
# callbacks调用上述保存模型的方法
history = model.fit(
    xTrain,
    yTrain,
    batch_size=8,
    validation_data=(xTest, yTest),
    epochs=50,
    verbose=1,
    callbacks=[checkpoint],
)
# 至此模型训练完毕
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 129/166 [======================>.......] - ETA: 0s - loss: 2.0211 - sparse_categorical_accuracy: 0.2752
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.48193, saving model to best_model.h5
# 166/166 [==============================] - 1s 2ms/step - loss: 1.8281 - sparse_categorical_accuracy: 0.3291 - val_loss: 1.0332 - val_sparse_categorical_accuracy: 0.4819
# Epoch 2/50
# 153/166 [==========================>...] - ETA: 0s - loss: 1.0056 - sparse_categorical_accuracy: 0.5588
# Epoch 2: val_sparse_categorical_accuracy improved from 0.48193 to 0.68675, saving model to best_model.h5
# 166/166 [==============================] - 0s 2ms/step - loss: 0.9943 - sparse_categorical_accuracy: 0.5678 - val_loss: 0.8706 - val_sparse_categorical_accuracy: 0.6867
# Epoch 3/50
# 166/166 [==============================] - ETA: 0s - loss: 0.8204 - sparse_categorical_accuracy: 0.6995
# Epoch 3: val_sparse_categorical_accuracy improved from 0.68675 to 0.77108, saving model to best_model.h5
# 166/166 [==============================] - 0s 2ms/step - loss: 0.8204 - sparse_categorical_accuracy: 0.6995 - val_loss: 0.7069 - val_sparse_categorical_accuracy: 0.7711
# Epoch 4/50
# 133/166 [=======================>......] - ETA: 0s - loss: 0.6970 - sparse_categorical_accuracy: 0.7444
# Epoch 4: val_sparse_categorical_accuracy improved from 0.77108 to 0.78012, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 0.6801 - sparse_categorical_accuracy: 0.7500 - val_loss: 0.5795 - val_sparse_categorical_accuracy: 0.7801
# Epoch 5/50
# 127/166 [=====================>........] - ETA: 0s - loss: 0.5837 - sparse_categorical_accuracy: 0.7667
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.78012
# 166/166 [==============================] - 0s 1ms/step - loss: 0.5760 - sparse_categorical_accuracy: 0.7726 - val_loss: 0.5148 - val_sparse_categorical_accuracy: 0.7771
# Epoch 6/50
# 162/166 [============================>.] - ETA: 0s - loss: 0.5145 - sparse_categorical_accuracy: 0.7863
# Epoch 6: val_sparse_categorical_accuracy improved from 0.78012 to 0.95783, saving model to best_model.h5
# 166/166 [==============================] - 0s 2ms/step - loss: 0.5133 - sparse_categorical_accuracy: 0.7892 - val_loss: 0.4457 - val_sparse_categorical_accuracy: 0.9578
# Epoch 7/50
# 162/166 [============================>.] - ETA: 0s - loss: 0.4624 - sparse_categorical_accuracy: 0.8434
# Epoch 7: val_sparse_categorical_accuracy improved from 0.95783 to 0.98193, saving model to best_model.h5
# 166/166 [==============================] - 0s 2ms/step - loss: 0.4637 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.3901 - val_sparse_categorical_accuracy: 0.9819
# Epoch 8/50
# 127/166 [=====================>........] - ETA: 0s - loss: 0.4193 - sparse_categorical_accuracy: 0.8622
# Epoch 8: val_sparse_categorical_accuracy improved from 0.98193 to 0.98795, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 0.4156 - sparse_categorical_accuracy: 0.8682 - val_loss: 0.3489 - val_sparse_categorical_accuracy: 0.9880
# Epoch 9/50
# 160/166 [===========================>..] - ETA: 0s - loss: 0.3574 - sparse_categorical_accuracy: 0.8992
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.98795
# 166/166 [==============================] - 0s 2ms/step - loss: 0.3609 - sparse_categorical_accuracy: 0.8991 - val_loss: 0.2955 - val_sparse_categorical_accuracy: 0.9578
# Epoch 10/50
# 124/166 [=====================>........] - ETA: 0s - loss: 0.3041 - sparse_categorical_accuracy: 0.9224
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.98795
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2957 - sparse_categorical_accuracy: 0.9255 - val_loss: 0.2137 - val_sparse_categorical_accuracy: 0.9699
# Epoch 11/50
# 124/166 [=====================>........] - ETA: 0s - loss: 0.2652 - sparse_categorical_accuracy: 0.9143
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.98795
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2649 - sparse_categorical_accuracy: 0.9172 - val_loss: 0.2054 - val_sparse_categorical_accuracy: 0.9880
# Epoch 12/50
# 130/166 [======================>.......] - ETA: 0s - loss: 0.2378 - sparse_categorical_accuracy: 0.9202
# Epoch 12: val_sparse_categorical_accuracy improved from 0.98795 to 0.99398, saving model to best_model.h5
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2309 - sparse_categorical_accuracy: 0.9247 - val_loss: 0.1354 - val_sparse_categorical_accuracy: 0.9940
# Epoch 13/50
# 133/166 [=======================>......] - ETA: 0s - loss: 0.2084 - sparse_categorical_accuracy: 0.9342
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.99398
# 166/166 [==============================] - 0s 1ms/step - loss: 0.2028 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.1099 - val_sparse_categorical_accuracy: 0.9849
# Epoch 14/50
# 163/166 [============================>.] - ETA: 0s - loss: 0.1855 - sparse_categorical_accuracy: 0.9486
# Epoch 14: val_sparse_categorical_accuracy improved from 0.99398 to 0.99699, saving model to best_model.h5
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1851 - sparse_categorical_accuracy: 0.9488 - val_loss: 0.0932 - val_sparse_categorical_accuracy: 0.9970
# Epoch 15/50
# 166/166 [==============================] - ETA: 0s - loss: 0.1511 - sparse_categorical_accuracy: 0.9623
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1511 - sparse_categorical_accuracy: 0.9623 - val_loss: 0.0875 - val_sparse_categorical_accuracy: 0.9910
# Epoch 16/50
# 129/166 [======================>.......] - ETA: 0s - loss: 0.1537 - sparse_categorical_accuracy: 0.9593
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1509 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.0624 - val_sparse_categorical_accuracy: 0.9910
# Epoch 17/50
# 165/166 [============================>.] - ETA: 0s - loss: 0.1370 - sparse_categorical_accuracy: 0.9682
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1364 - sparse_categorical_accuracy: 0.9684 - val_loss: 0.0498 - val_sparse_categorical_accuracy: 0.9910
# Epoch 18/50
# 126/166 [=====================>........] - ETA: 0s - loss: 0.1457 - sparse_categorical_accuracy: 0.9563
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1403 - sparse_categorical_accuracy: 0.9541 - val_loss: 0.0642 - val_sparse_categorical_accuracy: 0.9940
# Epoch 19/50
# 161/166 [============================>.] - ETA: 0s - loss: 0.1188 - sparse_categorical_accuracy: 0.9713
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1199 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.0461 - val_sparse_categorical_accuracy: 0.9910
# Epoch 20/50
# 154/166 [==========================>...] - ETA: 0s - loss: 0.1019 - sparse_categorical_accuracy: 0.9708
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.1055 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.0333 - val_sparse_categorical_accuracy: 0.9940
# Epoch 21/50
# 163/166 [============================>.] - ETA: 0s - loss: 0.1037 - sparse_categorical_accuracy: 0.9655
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1025 - sparse_categorical_accuracy: 0.9661 - val_loss: 0.0477 - val_sparse_categorical_accuracy: 0.9849
# Epoch 22/50
# 165/166 [============================>.] - ETA: 0s - loss: 0.0911 - sparse_categorical_accuracy: 0.9735
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0909 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0363 - val_sparse_categorical_accuracy: 0.9880
# Epoch 23/50
# 166/166 [==============================] - ETA: 0s - loss: 0.0849 - sparse_categorical_accuracy: 0.9774
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0849 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0308 - val_sparse_categorical_accuracy: 0.9940
# Epoch 24/50
# 161/166 [============================>.] - ETA: 0s - loss: 0.1025 - sparse_categorical_accuracy: 0.9651
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.1010 - sparse_categorical_accuracy: 0.9654 - val_loss: 0.0275 - val_sparse_categorical_accuracy: 0.9970
# Epoch 25/50
# 125/166 [=====================>........] - ETA: 0s - loss: 0.0861 - sparse_categorical_accuracy: 0.9810
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0889 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0265 - val_sparse_categorical_accuracy: 0.9940
# Epoch 26/50
# 128/166 [======================>.......] - ETA: 0s - loss: 0.0793 - sparse_categorical_accuracy: 0.9795
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0834 - sparse_categorical_accuracy: 0.9789 - val_loss: 0.0237 - val_sparse_categorical_accuracy: 0.9940
# Epoch 27/50
# 127/166 [=====================>........] - ETA: 0s - loss: 0.0824 - sparse_categorical_accuracy: 0.9724
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0804 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0376 - val_sparse_categorical_accuracy: 0.9880
# Epoch 28/50
# 128/166 [======================>.......] - ETA: 0s - loss: 0.0645 - sparse_categorical_accuracy: 0.9785
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0738 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.0346 - val_sparse_categorical_accuracy: 0.9910
# Epoch 29/50
# 162/166 [============================>.] - ETA: 0s - loss: 0.0798 - sparse_categorical_accuracy: 0.9792
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0791 - sparse_categorical_accuracy: 0.9797 - val_loss: 0.0286 - val_sparse_categorical_accuracy: 0.9910
# Epoch 30/50
# 162/166 [============================>.] - ETA: 0s - loss: 0.0781 - sparse_categorical_accuracy: 0.9807
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0776 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.0212 - val_sparse_categorical_accuracy: 0.9940
# Epoch 31/50
# 128/166 [======================>.......] - ETA: 0s - loss: 0.0698 - sparse_categorical_accuracy: 0.9775
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0757 - sparse_categorical_accuracy: 0.9789 - val_loss: 0.0211 - val_sparse_categorical_accuracy: 0.9940
# Epoch 32/50
# 164/166 [============================>.] - ETA: 0s - loss: 0.0723 - sparse_categorical_accuracy: 0.9817
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0722 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.0197 - val_sparse_categorical_accuracy: 0.9910
# Epoch 33/50
# 130/166 [======================>.......] - ETA: 0s - loss: 0.0705 - sparse_categorical_accuracy: 0.9798
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0678 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.0284 - val_sparse_categorical_accuracy: 0.9880
# Epoch 34/50
# 165/166 [============================>.] - ETA: 0s - loss: 0.0722 - sparse_categorical_accuracy: 0.9803
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0719 - sparse_categorical_accuracy: 0.9804 - val_loss: 0.0146 - val_sparse_categorical_accuracy: 0.9940
# Epoch 35/50
# 160/166 [===========================>..] - ETA: 0s - loss: 0.0637 - sparse_categorical_accuracy: 0.9805
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0623 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.0129 - val_sparse_categorical_accuracy: 0.9970
# Epoch 36/50
# 151/166 [==========================>...] - ETA: 0s - loss: 0.0661 - sparse_categorical_accuracy: 0.9834
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0680 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.0259 - val_sparse_categorical_accuracy: 0.9910
# Epoch 37/50
# 159/166 [===========================>..] - ETA: 0s - loss: 0.0573 - sparse_categorical_accuracy: 0.9858
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0572 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 0.9970
# Epoch 38/50
# 158/166 [===========================>..] - ETA: 0s - loss: 0.0582 - sparse_categorical_accuracy: 0.9842
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0571 - sparse_categorical_accuracy: 0.9849 - val_loss: 0.0150 - val_sparse_categorical_accuracy: 0.9970
# Epoch 39/50
# 151/166 [==========================>...] - ETA: 0s - loss: 0.0616 - sparse_categorical_accuracy: 0.9843
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0673 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 0.9940
# Epoch 40/50
# 156/166 [===========================>..] - ETA: 0s - loss: 0.0548 - sparse_categorical_accuracy: 0.9872
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.0157 - val_sparse_categorical_accuracy: 0.9940
# Epoch 41/50
# 127/166 [=====================>........] - ETA: 0s - loss: 0.0578 - sparse_categorical_accuracy: 0.9833
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0542 - sparse_categorical_accuracy: 0.9849 - val_loss: 0.0401 - val_sparse_categorical_accuracy: 0.9910
# Epoch 42/50
# 163/166 [============================>.] - ETA: 0s - loss: 0.0630 - sparse_categorical_accuracy: 0.9854
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0624 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0137 - val_sparse_categorical_accuracy: 0.9940
# Epoch 43/50
# 165/166 [============================>.] - ETA: 0s - loss: 0.0515 - sparse_categorical_accuracy: 0.9894
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0513 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.0149 - val_sparse_categorical_accuracy: 0.9940
# Epoch 44/50
# 158/166 [===========================>..] - ETA: 0s - loss: 0.0658 - sparse_categorical_accuracy: 0.9834
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0637 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.0281 - val_sparse_categorical_accuracy: 0.9910
# Epoch 45/50
# 143/166 [========================>.....] - ETA: 0s - loss: 0.0721 - sparse_categorical_accuracy: 0.9860
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0679 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0176 - val_sparse_categorical_accuracy: 0.9910
# Epoch 46/50
# 158/166 [===========================>..] - ETA: 0s - loss: 0.0794 - sparse_categorical_accuracy: 0.9747
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0774 - sparse_categorical_accuracy: 0.9752 - val_loss: 0.0111 - val_sparse_categorical_accuracy: 0.9970
# Epoch 47/50
# 162/166 [============================>.] - ETA: 0s - loss: 0.0584 - sparse_categorical_accuracy: 0.9807
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0584 - sparse_categorical_accuracy: 0.9804 - val_loss: 0.0094 - val_sparse_categorical_accuracy: 0.9940
# Epoch 48/50
# 160/166 [===========================>..] - ETA: 0s - loss: 0.0552 - sparse_categorical_accuracy: 0.9883
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0552 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.0381 - val_sparse_categorical_accuracy: 0.9910
# Epoch 49/50
# 162/166 [============================>.] - ETA: 0s - loss: 0.0540 - sparse_categorical_accuracy: 0.9853
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 2ms/step - loss: 0.0529 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.0163 - val_sparse_categorical_accuracy: 0.9940
# Epoch 50/50
# 164/166 [============================>.] - ETA: 0s - loss: 0.0539 - sparse_categorical_accuracy: 0.9901
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.99699
# 166/166 [==============================] - 0s 1ms/step - loss: 0.0535 - sparse_categorical_accuracy: 0.9902 - val_loss: 0.0222 - val_sparse_categorical_accuracy: 0.9940

# %%
# 加载模型
model = load_model(filepath)
# 模型推理，预测
predictions = model.predict(xTest)
predictions = np.argmax(predictions, axis=1)
# 查看混淆矩阵，效果越好，预测则集中在对角线。
cm = confusion_matrix(yTest, predictions)
print(cm)
# Out:
# 11/11 [==============================] - 0s 909us/step
# [[ 68   0   0   0]
#  [  0  84   0   0]
#  [  0   0  76   0]
#  [  1   0   0 103]]

# %% [markdown]
# 由于运动状态简单，上述最简单的模型可能也会获得不错的性能，当运动状态变得复杂，上述MLP模型性能将很难满足需求。
# #### 04 生成最终部署的模型
# 由于RIOT系统使用的时tflite-micro库且资源有限，将模型量化，并保存成tflite-micro可识别的格式，注意
# `data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, ))`后的尺寸维度和大小需要和前面大致对应

# %%
# Convert the model to the TensorFlow Lite format with quantization
# 加载模型
model = load_model(filepath)
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# 设置目标操作集，允许使用 TensorFlow 原生操作
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,  # 使用TFLite的内置操作
    tf.lite.OpsSet.SELECT_TF_OPS     # 允许使用部分TensorFlow的操作
]

# 禁用 tensor list ops 的低级优化
converter._experimental_lower_tensor_list_ops = False

tflite_model = converter.convert()
# 保存初始版本，后续对比用
open("model_basic.tflite", "wb").write(tflite_model)
open("model.tflite", "wb").write(tflite_model)

# 量化模型, 定义输入格式与大小，只需要修改(-1, 6 * SAMPLES_PER_GESTURE,)与上面对应即可，其余不用变
data_test = xTest.astype("float32")
# np.reshape 和一开始数据集导入对应
# MLP
# data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, ))
# CNN 1
# data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, 1))
# CNN 2
data_test = np.reshape(data_test, (-1, SAMPLES_PER_GESTURE, 6, 1))
data_ds = tf.data.Dataset.from_tensor_slices((data_test)).batch(1)

# Rest of your code...
def representative_data_gen():
    for input_value in data_ds.take(100):
        yield [input_value]
converter.representative_dataset = representative_data_gen
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()
open("model.tflite", "wb").write(tflite_model)

# 量化前后对比
basic_model_size = os.path.getsize("model_basic.tflite")
print("Basic model is %d bytes" % basic_model_size)
quantized_model_size = os.path.getsize("model.tflite")
print("Quantized model is %d bytes" % quantized_model_size)
difference = basic_model_size - quantized_model_size
print("Difference is %d bytes" % difference)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp_ejsi62n/assets
# INFO:tensorflow:Assets written to: /tmp/tmp_ejsi62n/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# INFO:tensorflow:Assets written to: /tmp/tmpjrwlrxbp/assets
# INFO:tensorflow:Assets written to: /tmp/tmpjrwlrxbp/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# /usr/local/lib/python3.8/dist-packages/tensorflow/lite/python/convert.py:887: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Basic model is 6652 bytes
# Quantized model is 5336 bytes
# Difference is 1316 bytes
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32

# %% [markdown]
# 前面，通过量化，帮助我们模型节省了2440Bytes大小。需要验证量化后的模型输入格式和尺寸是否正确

# %%
# Now let's verify the model on a few input digits
# Instantiate an interpreter for the model
model_quantized_reloaded = tf.lite.Interpreter("model.tflite")

# Allocate memory for each model
model_quantized_reloaded.allocate_tensors()

# Get the input and output tensors so we can feed in values and get the results
model_quantized_input = model_quantized_reloaded.get_input_details()[0]["index"]
model_quantized_output = model_quantized_reloaded.get_output_details()[0]["index"]
# Create arrays to store the results
model_quantized_predictions = np.empty(xTest.size)

count = 0

for i in range(yTest.shape[0]):
    # Reshape the data and ensure the type is float32
    # test_data = np.reshape(
    #     xTest[i],
    #     (
    #         1,
    #         6 * SAMPLES_PER_GESTURE,
    #         1,
    #     ),
    # ).astype("float32")
    test_data = np.expand_dims(xTest[i], axis=0).astype("float32")
    print(test_data.shape)
    # Invoke the interpreter
    model_quantized_reloaded.set_tensor(model_quantized_input, test_data)
    model_quantized_reloaded.invoke()
    model_quantized_prediction = model_quantized_reloaded.get_tensor(
        model_quantized_output
    )
    result = np.argmax(model_quantized_prediction, axis=1)
    if (result == yTest[i]):
        count = count + 1
    print("Digit: {} - Prediction:\n{}".format(yTest[i], model_quantized_prediction))
    print("")

print(count / yTest.shape[0])
# Out:
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.31640625 0.31640625 0.0546875  0.31640625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.  0.  0.5 0.5]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.  0.  0.5 0.5]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.        0.        0.8515625 0.1484375]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.12890625 0.00390625 0.12890625 0.7421875 ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.97265625 0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.31640625 0.31640625 0.0546875  0.31640625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.  0.  0.5 0.5]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.97265625 0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.0234375  0.         0.14453125 0.83203125]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.14453125 0.84765625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.9453125  0.         0.02734375]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.97265625 0.02734375]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.02734375 0.02734375 0.02734375 0.91796875]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.97265625 0.02734375]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.97265625 0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.0234375  0.         0.14453125 0.83203125]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.078125   0.00390625 0.4609375  0.4609375 ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.  0.  0.5 0.5]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.02734375 0.96484375]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.  0.  0.5 0.5]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.453125   0.01171875 0.078125   0.453125  ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.02734375 0.02734375 0.02734375 0.91796875]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.97265625 0.02734375]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.97265625 0.02734375]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.  0.  0.5 0.5]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.97265625 0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.31640625 0.31640625 0.0546875  0.31640625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.14453125 0.84765625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.96875   ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.  0.  0.5 0.5]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.12890625 0.00390625 0.12890625 0.7421875 ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.96875   ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.0234375  0.00390625 0.14453125 0.828125  ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.14453125 0.84765625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.125     0.125     0.0234375 0.7265625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.00390625 0.         0.14453125 0.84765625]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.02734375 0.97265625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.83203125 0.         0.0234375 ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.  0.  0.5 0.5]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.14453125 0.84765625 0.         0.00390625]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.453125   0.453125   0.01171875 0.078125  ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.        0.        0.1484375 0.8515625]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.  0.  0.5 0.5]]
#
# (1, 10, 6, 1)
# Digit: 0.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 3.0 - Prediction:
# [[0.7265625 0.0234375 0.125     0.125    ]]
#
# (1, 10, 6, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.96875    0.         0.        ]]
#
# (1, 10, 6, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.99609375 0.        ]]
#
# 0.927710843373494
